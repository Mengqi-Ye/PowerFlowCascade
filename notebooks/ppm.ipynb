# %%
import pandas as pd
import powerplantmatching as pm
# Out:
# Cartopy not existent.

# %%
cfg = pm.core.get_config(filename=".powerplantmatching_config_update.yaml")

# %%
opsd = pm.data.OPSD(config=cfg)
opsd.head()
# Out:
# Empty DataFrame
# Columns: [Name, Fueltype, Technology, Set, Country, Capacity, Efficiency, DateIn, DateRetrofit, DateOut, lat, lon, Duration, Volume_Mm3, DamHeight_m, StorageCapacity_MWh, EIC, projectID]
# Index: []

# %%
geo = pm.data.GEO(config=cfg)
geo.head()
# Out:
# GEO                  Name   Fueltype Technology Set  Country    Capacity  \
# 0    Pha Lai Coal Vietnam        Oil        NaN  PP  Vietnam  277.900649
# 1    Pha Lai Coal Vietnam        Oil        NaN  PP  Vietnam  277.900649
# 2    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
# 3    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
# 4    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
#
# GEO  Efficiency  DateIn  DateRetrofit  DateOut      lat       lon  Duration  \
# 0           NaN  2001.0           NaN      NaN  21.1165  106.3068       NaN
# 1           NaN  2001.0           NaN      NaN  21.1165  106.3068       NaN
# 2           NaN  1983.0           NaN      NaN  21.1155  106.3090       NaN
# 3           NaN  1983.0           NaN      NaN  21.1155  106.3090       NaN
# 4           NaN  1983.0           NaN      NaN  21.1155  106.3090       NaN
#
# GEO  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  EIC  projectID
# ...

# %%
gpd = pm.data.GPD(config=cfg)
gpd.head()
# Out:
# GPD          Name     Fueltype Technology Set  Country  Capacity  Efficiency  \
# 0           Amata          Oil        NaN  PP  Vietnam      13.0         NaN
# 1        An Khanh    Hard Coal        NaN  PP  Vietnam     120.0         NaN
# 2    An Khe Kanak        Hydro        NaN  PP  Vietnam     173.0         NaN
# 3         Ayun Ha        Hydro        NaN  PP  Vietnam       3.0         NaN
# 4          Ba Ria  Natural Gas       CCGT  PP  Vietnam     389.0         NaN
#
# GPD  DateIn  DateRetrofit  DateOut      lat       lon  Duration  Volume_Mm3  \
# 0       NaN           NaN      NaN  10.9471  106.9000       NaN         NaN
# 1    2015.0           NaN      NaN  21.5969  105.7670       NaN         NaN
# 2    2009.0           NaN      NaN  14.0148  108.6796       NaN         NaN
# 3       NaN           NaN      NaN  13.5809  108.2592       NaN         NaN
# 4       NaN           NaN      NaN  10.4891  107.1700       NaN         NaN
#
# ...

# %%
gbpt = pm.data.GBPT(config=cfg)
gbpt.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5780\4089219007.py in ?()
# ----> 1 gbpt = pm.data.GBPT(config=cfg)
#       2 gbpt.head()
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\powerplantmatching\data.py in ?(raw, update, config)
#    1643     status_list = config["GBPT"].get("status", ["operating"])  # noqa: F841
#    1644
#    1645     df = df.rename(columns=RENAME_COLUMNS)
#    1646     df_final = (
# -> 1647         df.pipe(clean_name)
#    1648         .pipe(set_column_name, "GBPT")
#    1649         .pipe(convert_to_short_name)
#    1650         .dropna(subset="Capacity")
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\pandas\core\generic.py in ?(self, func, *args, **kwargs)
#    6227         2  3682.80  1473.12
#    6228         """
#    6229         if using_copy_on_write():
# ...

# %%
gcpt = pm.data.GCPT(config=cfg)
gcpt.head()
# Out:
# GCPT      Name   Fueltype     Technology Set  Country  Capacity  Efficiency  \
# 0     An Khanh  Hard Coal  Steam Turbine  PP  Vietnam      50.0         NaN
# 1     An Khanh  Hard Coal  Steam Turbine  PP  Vietnam      50.0         NaN
# 2      Cam Pha  Hard Coal  Steam Turbine  PP  Vietnam     340.0         NaN
# 3      Cam Pha  Hard Coal  Steam Turbine  PP  Vietnam     340.0         NaN
# 4     Cao Ngan  Hard Coal  Steam Turbine  PP  Vietnam      57.5         NaN
#
# GCPT  DateIn  DateRetrofit  DateOut        lat         lon  Duration  \
# 0     2015.0           NaN      NaN  21.596912  105.766609       NaN
# 1     2015.0           NaN      NaN  21.596912  105.766609       NaN
# 2     2011.0           NaN      NaN  21.006288  107.358044       NaN
# 3     2011.0           NaN      NaN  21.006288  107.358044       NaN
# 4     2006.0           NaN      NaN  21.612998  105.815102       NaN
#
# GCPT  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  EIC      projectID
# ...

# %%
ggpt = pm.data.GGPT(config=cfg)
ggpt.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5780\1187713683.py in ?()
# ----> 1 ggpt = pm.data.GGPT(config=cfg)
#       2 ggpt.head()
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\powerplantmatching\data.py in ?(raw, update, config)
#    2040     df = df.rename(columns=RENAME_COLUMNS)
#    2041     df_final = (
#    2042         df.pipe(clean_name)
#    2043         .pipe(set_column_name, "GGPT")
# -> 2044         .pipe(convert_to_short_name)
#    2045         .dropna(subset="Capacity")
#    2046         .pipe(lambda x: x.query("Capacity != 'not found'"))
#    2047         .assign(
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\pandas\core\generic.py in ?(self, func, *args, **kwargs)
#    6227         2  3682.80  1473.12
#    6228         """
#    6229         if using_copy_on_write():
# ...

# %%
ggtpt = pm.data.GGTPT(config=cfg)
ggtpt.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5780\4086613230.py in ?()
# ----> 1 ggtpt = pm.data.GGTPT(config=cfg)
#       2 ggtpt.head()
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\powerplantmatching\data.py in ?(raw, update, config)
#    1836     df_final = (
#    1837         df.pipe(clean_name)
#    1838         .pipe(set_column_name, "GGTPT")
#    1839         .pipe(convert_to_short_name)
# -> 1840         .dropna(subset="Capacity")
#    1841         .assign(
#    1842             DateIn=df["DateIn"].apply(pd.to_numeric, errors="coerce"),
#    1843             DateOut=df["DateOut"].apply(pd.to_numeric, errors="coerce"),
#
# c:\Users\mye500\AppData\Local\anaconda3\envs\py311\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
# ...

# %%
gnpt = pm.data.GNPT(config=cfg)
gnpt.head()
# Out:
# Empty DataFrame
# Columns: [Name, Fueltype, Technology, Set, Country, Capacity, Efficiency, DateIn, DateRetrofit, DateOut, lat, lon, Duration, Volume_Mm3, DamHeight_m, StorageCapacity_MWh, EIC, projectID]
# Index: []

# %%
gspt = pm.data.GSPT(config=cfg)
gspt.head()
# Out:
# GSPT                            Name Fueltype Technology Set  Country  \
# 0                   An Cu Solar Farm    Solar         PV  PP  Vietnam
# 1        An Giang Sao Mai Solar Farm    Solar         PV  PP  Vietnam
# 2        An Giang Sao Mai Solar Farm    Solar         PV  PP  Vietnam
# 3     Ba Ria Vung Tau Province Solar    Solar         PV  PP  Vietnam
# 4              Bac Ai District Solar    Solar         PV  PP  Vietnam
#
# GSPT  Capacity  Efficiency  DateIn  DateRetrofit  DateOut      lat       lon  \
# 0         50.0         NaN     NaN           NaN      NaN  10.5095  105.1478
# 1        104.0         NaN  2019.0           NaN      NaN  10.4655  105.0124
# 2        106.0         NaN  2020.0           NaN      NaN  10.5579  104.9915
# 3         16.3         NaN  2020.0           NaN      NaN  10.5862  107.0435
# 4          5.0         NaN  2020.0           NaN      NaN  11.6611  108.9623
#
# GSPT  Duration  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  EIC  \
# ...

# %%
gwpt = pm.data.GWPT(config=cfg)
gwpt.head()
# Out:
# GWPT                                 Name Fueltype Technology Set  Country  \
# 0        Bac Lieu Kosy Offshore Wind Farm     Wind   Offshore  PP  Vietnam
# 1             Bac Lieu Offshore Wind Farm     Wind   Offshore  PP  Vietnam
# 2             Bac Lieu Offshore Wind Farm     Wind   Offshore  PP  Vietnam
# 3     Ben Tre Binh Dai Offshore Wind Farm     Wind   Offshore  PP  Vietnam
# 4     Ben Tre Binh Dai Offshore Wind Farm     Wind   Offshore  PP  Vietnam
#
# GWPT  Capacity  Efficiency  DateIn  DateRetrofit  DateOut      lat       lon  \
# 0         40.5         NaN  2021.0           NaN      NaN   9.1718  105.6710
# 1         16.0         NaN  2013.0           NaN      NaN   9.2367  105.8223
# 2         83.0         NaN  2014.0           NaN      NaN   9.2367  105.8223
# 3         49.0         NaN  2021.0           NaN      NaN  10.1507  106.8010
# 4         30.0         NaN  2022.0           NaN      NaN  10.0954  106.8110
#
# ...

# %%
jrc = pm.data.JRC(config=cfg)
jrc.head()
# Out:
# Empty DataFrame
# Columns: [Name, Fueltype, Technology, Set, Country, Capacity, Efficiency, DateIn, DateRetrofit, DateOut, lat, lon, Duration, Volume_Mm3, DamHeight_m, StorageCapacity_MWh, EIC, projectID]
# Index: []

# %%
dfs = [gpd.powerplant.aggregate_units(), geo.powerplant.aggregate_units()]
intersection = pm.matching.combine_multiple_datasets(dfs)
# Out:
# No matches found

# %%
gwpt.powerplant.lookup().head(20).to_frame()
# Out:
#                   Capacity
# Country Fueltype
# Vietnam Wind        7403.1

# %%
geo.powerplant.fill_missing_commissioning_years().head()
# Out:
# GEO                  Name   Fueltype Technology Set  Country    Capacity  \
# 0    Pha Lai Coal Vietnam        Oil        NaN  PP  Vietnam  277.900649
# 1    Pha Lai Coal Vietnam        Oil        NaN  PP  Vietnam  277.900649
# 2    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
# 3    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
# 4    Pha Lai Coal Vietnam  Hard Coal        NaN  PP  Vietnam  101.413065
#
# GEO  Efficiency  DateIn  DateRetrofit  DateOut      lat       lon  Duration  \
# 0           NaN  2001.0        2001.0      NaN  21.1165  106.3068       NaN
# 1           NaN  2001.0        2001.0      NaN  21.1165  106.3068       NaN
# 2           NaN  1983.0        1983.0      NaN  21.1155  106.3090       NaN
# 3           NaN  1983.0        1983.0      NaN  21.1155  106.3090       NaN
# 4           NaN  1983.0        1983.0      NaN  21.1155  106.3090       NaN
#
# GEO  Volume_Mm3  DamHeight_m  StorageCapacity_MWh  EIC  projectID
# ...
